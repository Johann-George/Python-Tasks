# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# %%
# Use the model
results = model.train(data='data.yaml', epochs=50)  # train the model
results = model.val(data='data.yaml')  # evaluate model performance on the validation set
# Out:
# Ultralytics 8.3.228  Python-3.12.3 torch-2.9.1+cpu CPU (11th Gen Intel Core i7-11800H @ 2.30GHz)
# ...

# %%
from PIL import Image

#Testing 
# model = YOLO('')
results = model([
    'C:/Users/johan/Downloads/Yolo_Task/test/images/63228_78022002696_4063-00048.jpg',
    'C:/Users/johan/Downloads/Yolo_Task/test/images/63228_78022002696_4063-00050.jpg',
    'C:/Users/johan/Downloads/Yolo_Task/test/images/63228_78022002696_4063-00063.jpg',
    'C:/Users/johan/Downloads/Yolo_Task/test/images/63228_78022002696_4063-00022.jpg',
    'C:/Users/johan/Downloads/Yolo_Task/test/images/63228_78022002696_4063-00041.jpg'
])  # predict on an image

for i, r in enumerate(results):
    # Plot results image
    im_bgr = r.plot()  # BGR-order numpy array
    im_rgb = Image.fromarray(im_bgr[..., ::-1])  # RGB-order PIL image

    # Show results to screen (in supported environments)
    r.show()

    # Save results to disk
    r.save(filename=f"results{i}.jpg")

# results = model.export(format='onnx')  # export the model to ONNX format
# Out:
# 0: 640x640 2 Full Addresss, 1 Description of Qualifying Property, 1 Number of Electors, 1 Place of Abode, 1 Nature of Qualification, 51.7ms
# 1: 640x640 1 Full Address, 1 Description of Qualifying Property, 1 Number of Electors, 1 Place of Abode, 1 Nature of Qualification, 51.7ms
# 2: 640x640 5 Full Addresss, 1 Description of Qualifying Property, 1 Number of Electors, 1 Place of Abode, 1 Nature of Qualification, 51.7ms
# 3: 640x640 5 Full Addresss, 1 Description of Qualifying Property, 1 Number of Electors, 1 Place of Abode, 1 Nature of Qualification, 51.7ms
# 4: 640x640 14 Full Addresss, 1 Description of Qualifying Property, 1 Number of Electors, 1 Place of Abode, 1 Nature of Qualification, 51.7ms
# Speed: 3.8ms preprocess, 51.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
